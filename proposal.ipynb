# %% [markdown]
# # Testing

# %% [markdown]
# Testing Polymarket Data Loading Gamma API

# %%
import requests
import json

poly_url = "https://gamma-api.polymarket.com/events?limit=5"
response = requests.get(poly_url)

data = response.json()
print(data[0].get('title', 'N/A'))
# Out:
# NBA: Will the Mavericks beat the Grizzlies by more than 5.5 points in their December 4 matchup?

# %% [markdown]
# Testing Kalshi Data Loading API

# %%
import requests

kalshi_url = "https://api.elections.kalshi.com/trade-api/v2/series/KXHIGHNY"
response = requests.get(kalshi_url)
series_data = response.json()

print(f"Series Title: {series_data['series']['title']}")
print(f"Frequency: {series_data['series']['frequency']}")
print(f"Category: {series_data['series']['category']}")
# Out:
# Series Title: Highest temperature in NYC
# Frequency: daily
# Category: Climate and Weather
